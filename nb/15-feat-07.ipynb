# %%
import sys
sys.path.append("..")
from lib import ipy
import matplotlib.pylab as pl
import numpy as np

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pl.rcParams['figure.figsize'] = [10.0, 8.0]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
feat = ipy.load_feature(7)
ipy.overview(feat)
# Out:
# Loading from ../tests/out/seed=42/07-reward-state.txt
#                   0             1
# count  4.857976e+06  4.857976e+06
# mean  -7.497216e-03 -5.026985e-07
# std    1.452512e+00  9.999998e-01
# min   -6.666016e+01 -6.103122e-01
# 25%    0.000000e+00 -6.103122e-01
# 50%    0.000000e+00 -6.103122e-01
# 75%    0.000000e+00  4.513526e-01
# max    6.000000e+01  4.636621e+00

# %%
mask = ipy.bounds_feat(feat, (-1, -0.5))
sum(mask)
# Out:
# 3100792

# %%
ipy.scatter_mask(feat, mask)

# %%
set(feat[1][mask])
# Out:
# {-0.61031222340000002}

# %%
centers = ipy.cluster_1D(feat[1])
deltas = ipy.deltas(centers)

# %% [markdown]
# ## Stripe 1

# %%
start = 1
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000319, max=0.000319
# prev=0.402417, succ=0.216585
# 0.0003188861118638514

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=-0.207895, max=-0.189081, prev=-0.610312, succ=0.027504
# (-0.20789527889998632, -0.1890809983000191)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 273072 (5.6211%)

# %% [markdown]
# ## Stripe 2

# %%
start = 61
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000505, max=0.000505
# prev=0.216585, succ=0.137198
# 0.00050542197457624483

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=0.027504, max=0.057323, prev=-0.189081, succ=0.194522
# (0.027503540699999978, 0.057323437199998425)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 112748 (2.3209%)

# %% [markdown]
# ## Stripe 3

# %%
start = 121
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000638, max=0.000638
# prev=0.137198, succ=0.091921
# 0.00063777222372874949

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=0.194522, max=0.232150, prev=0.057323, succ=0.324071
# (0.19452168050000185, 0.23215024169999807)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 57276 (1.1790%)

# %% [markdown]
# ## Stripe 4

# %%
start = 181
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000740, max=0.000740
# prev=0.091921, succ=0.062164
# 0.00074043061694923187

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=0.324071, max=0.367756, prev=0.232150, succ=0.429921
# (0.32407099009999446, 0.36775639649999914)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 52496 (1.0806%)
