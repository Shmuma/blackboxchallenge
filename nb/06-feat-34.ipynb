# %%
import sys
sys.path.append("..")
from lib import ipy

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pl.rcParams['figure.figsize'] = [10.0, 8.0]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
feat = ipy.load_feature(34)
# Out:
# Loading from ../tests/out/seed=42/34-reward-state.txt

# %%
ipy.overview(feat)
# Out:
#                     0             1
# count  4857976.000000  4.857976e+06
# mean        -0.007497 -9.941496e-07
# std          1.452512  9.999994e-01
# min        -66.660160 -6.741731e+00
# 25%          0.000000 -5.175194e-01
# 50%          0.000000 -1.830249e-02
# 75%          0.000000  7.441451e-01
# max         60.000000  1.725520e+00

# %%
mask = ipy.bounds_feat(feat, [1.35, 1.8], no_zero_rw=True)
print sum(mask)
# Out:
# 23444

# %%
ipy.scatter_mask(feat, mask)

# %%
ipy.scatter_mask(feat, ipy.bounds_feat(feat, (1.1, 1.3)))

# %%
ipy.scatter_mask(feat, ipy.bounds_feat(feat, (-8, -6.7)))
