# %%
import sys
sys.path.append("..")
from lib import ipy
import matplotlib.pylab as pl
import numpy as np

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pl.rcParams['figure.figsize'] = [10.0, 8.0]

# %%
feat = ipy.load_feature(10)
# Out:
# Loading from ../tests/out/seed=42/10-reward-state.txt

# %%
ipy.overview(feat)
# Out:
#                   0             1
# count  4.857976e+06  4.857976e+06
# mean  -7.497216e-03 -6.636603e-07
# std    1.452512e+00  1.000000e+00
# min   -6.666016e+01 -8.129094e-01
# 25%    0.000000e+00 -7.740458e-01
# 50%    0.000000e+00 -7.398457e-01
# 75%    0.000000e+00  1.281833e+00
# max    6.000000e+01  1.654963e+00

# %%
dn_mask = ipy.bounds_feat(feat, (-1, -0.5))
sum(dn_mask)
# Out:
# 3060524

# %%
ipy.scatter_mask(feat, dn_mask)

# %%
dn_set = set(feat[1][dn_mask].values)

# %%
len(dn_set)
# Out:
# 60

# %%
centers = ipy.cluster_1D(feat[1])
deltas = ipy.deltas(centers)

# %% [markdown]
# ## Stripe 1

# %%
start = 0
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.001554, max=0.001555
# prev=0.007379, succ=2.003024
# 0.0015545467203457062

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=-0.812909, max=-0.721191, prev=1.654963, succ=1.281833
# (-0.8129093647002773, -0.7211911081998806)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 3060524 (63.0000%)

# %%
deltas[50:70]
# Out:
# [0.0015544891001202377,
#  0.001554667999796866,
#  0.001554429499446508,
#  0.0015544295996082758,
#  0.0015547275003867655,
#  0.0015544295011374887,
#  0.0015546679990023904,
#  0.0015544295002344333,
#  0.0015547275999523436,
#  2.0030242800287232,
#  0.08613860607087953,
#  6.675720020510312e-05,
#  6.699559997991322e-05,
#  6.675720013959996e-05,
#  6.687649989478572e-05,
#  6.687640007463358e-05,
#  6.687639988944838e-05,
#  6.675720019466702e-05,
#  6.699559988843085e-05,
#  6.675720003235242e-05]

# %%
centers[50:70]

# %% [markdown]
# ## Stripe 2

# %%
start = 61
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000067, max=0.000067
# prev=0.086139, succ=0.046444
# 6.6852166106599764e-05

# %%
t_mask = ipy.bounds_feat(feat, (1.281833-0.01, 1.281833+0.01))
ipy.scatter_mask(feat, t_mask)

# %%
sum(t_mask)
# Out:
# 1427480

# %%
set(feat[1][t_mask])
# Out:
# {1.2818331718}

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=1.367972, max=1.371916, prev=1.281833, succ=1.418360
# (1.367971777899722, 1.3719160557000114)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 252728 (5.2023%)

# %% [markdown]
# ## Stripe 3

# %%
start = 121
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000107, max=0.000107
# prev=0.046526, succ=0.029526
# 0.00010694285593263897

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=1.430607, max=1.436917, prev=1.384081, succ=1.466443
# (1.4306073189000015, 1.4369169474000272)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 54908 (1.1303%)

# %% [markdown]
# ## Stripe 4

# %%
start = 181
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000135, max=0.000135
# prev=0.029526, succ=0.019834
# 0.00013494693559368089

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=1.466443, max=1.474405, prev=1.436917, succ=1.494239
# (1.4664427041999817, 1.4744045734000089)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 20924 (0.4307%)
