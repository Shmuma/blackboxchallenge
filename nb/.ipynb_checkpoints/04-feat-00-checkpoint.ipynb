# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as pl
import seaborn as sb

# %matplotlib inline
# Out:
# /home/shmuma/sfw/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
from sklearn.cluster import KMeans

# %%
feat_00 = pd.read_csv("../tests/out/seed=42/00-reward-state.txt", header=None)

# %%
feat_00.describe()
# Out:
#                     0             1
# count  4857976.000000  4.857976e+06
# mean        -0.007497 -4.380874e-07
# std          1.452512  9.999998e-01
# min        -66.660160 -7.769827e-01
# 25%          0.000000 -7.129820e-01
# 50%          0.000000 -6.577087e-01
# 75%          0.000000  1.329640e+00
# max         60.000000  1.133517e+01

# %%
states_set = set(feat_00[1].values)
print len(states_set)
# Out:
# 300

# %%
slist = sorted(states_set)

# %%
deltas = []
prev = None
for v in slist:
    if prev is None:
        prev = v
        continue
    deltas.append(v-prev)
    prev = v

# %%
min_delta = min(deltas)

# %%
deltas = np.array(deltas)

# %%
pl.plot(filter(lambda v: v < 0.1, deltas))

# %%
pl.plot(deltas);

# %%
states_log = np.log10(np.array(list(states_set)) + 2)

# %%
pl.plot(slist);

# %%
pl.scatter(feat_00[0], feat_00[1], marker='.')

# %%
band_1 = feat_00[1] < 0

# %%
pl.scatter(feat_00[0][band_1], feat_00[1][band_1], marker='.')

# %%
pl.plot(sorted(feat_00[1][band_1]))

# %%
sum(band_1)
# Out:
# 3262424

# %%
band_2 = (feat_00[1] > 0) & (feat_00[1] < 2)
sum(band_2)
# Out:
# 1575772

# %%
pl.plot(sorted(feat_00[1][band_2]))

# %%
band_3 = (feat_00[1] > 2) & (feat_00[1] < 3.5)
sum(band_3)
# Out:
# 17532

# %%
pl.plot(sorted(feat_00[1][band_3]))
