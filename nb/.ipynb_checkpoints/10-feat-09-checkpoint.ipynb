# %%
import sys
sys.path.append("..")
from lib import ipy
import matplotlib.pylab as pl
import numpy as np

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pl.rcParams['figure.figsize'] = [10.0, 8.0]

# %%
feat_09 = ipy.load_feature(9)
# Out:
# Loading from ../tests/out/seed=42/09-reward-state.txt

# %%
ipy.overview(feat_09)
# Out:
#                   0             1
# count  4.857976e+06  4.857976e+06
# mean  -7.497216e-03 -7.066687e-07
# std    1.452512e+00  1.000000e+00
# min   -6.666016e+01 -8.065752e-01
# 25%    0.000000e+00 -7.673503e-01
# 50%    0.000000e+00 -7.328324e-01
# 75%    0.000000e+00  1.293758e+00
# max    6.000000e+01  1.698915e+00

# %%
dn_mask = ipy.bounds_feat(feat_09, (-1, -0.5))
sum(dn_mask)
# Out:
# 3080520

# %%
ipy.scatter_mask(feat_09, dn_mask)

# %%
dn_set = set(feat_09[1][dn_mask].values)

# %%
len(dn_set)
# Out:
# 60

# %%
feat = feat_09
centers = ipy.cluster_1D(feat[1])
deltas = ipy.deltas(centers)

# %% [markdown]
# ## Stripe 1

# %%
start = 0
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.001569, max=0.001569
# prev=0.033581, succ=2.007762
# 0.0015689952898412618

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=-0.806575, max=-0.714004, prev=1.698915, succ=1.293758
# (-0.806575179100036, -0.7140044569994015)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 3080520 (63.4116%)

# %% [markdown]
# ## Stripe 2

# %%
start = 61
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000067, max=0.000068
# prev=0.086342, succ=0.046526
# 6.747447965817151e-05

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=1.380100, max=1.384081, prev=1.293758, succ=1.430607
# (1.3801002502000435, 1.3840812444998756)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 252728 (5.2023%)

# %% [markdown]
# ## Stripe 3

# %%
start = 121
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000107, max=0.000107
# prev=0.046526, succ=0.029526
# 0.00010694285593263897

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=1.430607, max=1.436917, prev=1.384081, succ=1.466443
# (1.4306073189000015, 1.4369169474000272)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 54908 (1.1303%)

# %% [markdown]
# ## Stripe 4

# %%
start = 181
stop = start + 59
deltas_ = deltas[start:stop]
print "len=%d, min=%f, max=%f" % (len(deltas_), min(deltas_), max(deltas_))
print "prev=%f, succ=%f" % (deltas[start-1], deltas[stop])
np.mean(deltas_)
# Out:
# len=59, min=0.000107, max=0.000107
# prev=0.046526, succ=0.029526
# 0.00010694285593263897

# %%
centers_ = centers[start:stop+1]
print "len=%d, min=%f, max=%f, prev=%f, succ=%f" % (len(centers_), min(centers_),
                                                    max(centers_), centers[start-1], centers[stop+1])
min(centers_), max(centers_)
# Out:
# len=60, min=1.430607, max=1.436917, prev=1.384081, succ=1.466443
# (1.4306073189000015, 1.4369169474000272)

# %%
m = (feat[1] >= min(centers_)) & (feat[1] <= max(centers_))
count = sum(m)
print "%d (%.4f%%)" % (count, 100.0 * count / len(feat))
# Out:
# 54908 (1.1303%)
