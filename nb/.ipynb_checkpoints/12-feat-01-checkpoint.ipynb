# %%
import sys
sys.path.append("..")
from lib import ipy
import matplotlib.pylab as pl
import numpy as np

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pl.rcParams['figure.figsize'] = [10.0, 8.0]

# %%
feat_1 = ipy.load_feature(1)
ipy.overview(feat_1)
# Out:
# Loading from ../tests/out/seed=42/01-reward-state.txt
#                   0             1
# count  4.857976e+06  4.857976e+06
# mean  -7.497216e-03  2.662690e-06
# std    1.452512e+00  1.000000e+00
# min   -6.666016e+01 -1.414294e+00
# 25%    0.000000e+00 -9.832100e-01
# 50%    0.000000e+00 -5.752982e-01
# 75%    0.000000e+00  1.054981e+00
# max    6.000000e+01  1.572714e+00

# %%
mask_dn = ipy.bounds_feat(feat_1, (-2, -1))
sum(mask_dn)
# Out:
# 1098084

# %%
ipy.scatter_mask(feat_1, mask_dn)
