# %%
import sys
sys.path.append("..")
from lib import ipy
import matplotlib.pylab as pl

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pl.rcParams['figure.figsize'] = [10.0, 8.0]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
feat = ipy.load_feature(33)
# Out:
# Loading from ../tests/out/seed=42/33-reward-state.txt

# %%
ipy.overview(feat)
# Out:
#                     0               1
# count  4857976.000000  4857976.000000
# mean        -0.007497        0.000001
# std          1.452512        0.999999
# min        -66.660160       -5.329312
# 25%          0.000000       -0.322414
# 50%          0.000000        0.051654
# 75%          0.000000        0.648786
# max         60.000000        1.447598

# %%
feat_34 = ipy.load_feature(34)
# Out:
# Loading from ../tests/out/seed=42/34-reward-state.txt

# %%
pl.scatter(feat[1], feat_34[1], marker='.');

# %%
min_33 = feat[1].min()
min_34 = feat_34[1].min()
print min_33, min_34
f34_to_33_scale = min_33 / min_34
print f34_to_33_scale
# Out:
# -5.3293118477 -6.74173069
# 0.790496104451

# %%
mask = ipy.bounds_feat(feat, (0, 1), no_zero_rw=True)
mask_34 = ipy.bounds_feat(feat_34, (-1, 2), no_zero_rw=True)

# %%
pl.scatter(feat[1], f34_to_33_scale * feat_34[1], marker='.');

# %%
pl.scatter(feat[1][mask & mask_34], f34_to_33_scale * feat_34[1][mask & mask_34], marker='.');
