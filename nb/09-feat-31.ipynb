# %%
import sys
sys.path.append("..")
from lib import ipy
import matplotlib.pylab as pl

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pl.rcParams['figure.figsize'] = [10.0, 8.0]

# %%
feat_31 = ipy.load_feature(31)
# Out:
# Loading from ../tests/out/seed=42/31-reward-state.txt

# %%
ipy.overview(feat_31)
# Out:
#                   0             1
# count  4.857976e+06  4.857976e+06
# mean  -7.497216e-03  2.358963e-07
# std    1.452512e+00  9.999996e-01
# min   -6.666016e+01 -6.694309e+00
# 25%    0.000000e+00 -6.402014e-01
# 50%    0.000000e+00 -5.983413e-02
# 75%    0.000000e+00  5.189814e-01
# max    6.000000e+01  2.369039e+00
