# %%
import sys
sys.path.append("..")
from lib import ipy
import matplotlib.pylab as pl

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pl.rcParams['figure.figsize'] = [10.0, 8.0]

# %%
feat = ipy.load_feature(32)
# Out:
# Loading from ../tests/out/seed=42/32-reward-state.txt

# %%
ipy.overview(feat)
# Out:
#                   0             1
# count  4.857976e+06  4.857976e+06
# mean  -7.497216e-03 -4.148251e-07
# std    1.452512e+00  9.999988e-01
# min   -6.666016e+01 -7.100039e+00
# 25%    0.000000e+00 -6.951267e-01
# 50%    0.000000e+00 -1.272172e-01
# 75%    0.000000e+00  6.458073e-01
# max    6.000000e+01  2.432636e+00

# %%
feat_33 = ipy.load_feature(33)
# Out:
# Loading from ../tests/out/seed=42/33-reward-state.txt

# %%
feat_34 = ipy.load_feature(34)
# Out:
# Loading from ../tests/out/seed=42/34-reward-state.txt

# %%
pl.scatter(feat[1], feat_33[1], marker='.');

# %%
pl.scatter(feat[1] * feat_33[1], feat[0], marker='.');

# %%
mul_feat = feat[1] * feat_33[1]
div_feat = feat[1] / feat_33[1]

# %%
pl.scatter(feat[1] + feat_33[1], feat[0]/10, marker='.');

# %%
pl.scatter(feat[1] + feat_33[1], feat[0], marker='.');
